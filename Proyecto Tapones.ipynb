# %%
#TODO: Identifica todos los tapones
#TODO: Pinta un punto en el centro de cada tapon
#TODO: Al lado del punto muestra su área
#TODO: Al lado del área di que color tiene el tapon

#Los tapones se encuentran en la carpeta final_project_imgs

#BUENA SUERTE Y QUE COMIENCEN LOS JUEGOS DEL HAMBRE :) TQ

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-157-86cb628761ba> in <module>
#       5
#       6 for i in range(0, 8):
# ----> 7     images_copy_gray[i] = cv2.equalizeHist(images_copy[i])
#       8
#       9 ############################################
#
# error: OpenCV(4.2.0) /io/opencv/modules/imgproc/src/histogram.cpp:3439: error: (-215:Assertion failed) _src.type() == CV_8UC1 in function 'equalizeHist'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-45d3085dbbb3> in <module>
#       5 #Una vez todos los tapones sean negros, hago una mascara que coja solo los tapones
#       6 #Despues identificar el centro...
# ----> 7 images = [cv2.imread("final_project_imgs/%d.jpg"%(i)) for i in range(1, 9)]
#       8 images_copy = images.copy()
#       9 images_copy_gray = images.copy()
#
# <ipython-input-1-45d3085dbbb3> in <listcomp>(.0)
#       5 #Una vez todos los tapones sean negros, hago una mascara que coja solo los tapones
#       6 #Despues identificar el centro...
# ----> 7 images = [cv2.imread("final_project_imgs/%d.jpg"%(i)) for i in range(1, 9)]
#       8 images_copy = images.copy()
#       9 images_copy_gray = images.copy()
#
# NameError: name 'cv2' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f92bdcd7874b> in <module>
#       1 #En esta parte vamos a identificar el resto de tapones que no son rosas, a esos cabrones los dejamos para el final
# ----> 2 images = [cv2.imread("final_project_imgs/%d.jpg"%(i)) for i in range(1, 9)]
#       3 images_copy = images.copy()
#       4 images_copy_gray = images.copy()
#       5 images_aux = images.copy()
#
# <ipython-input-2-f92bdcd7874b> in <listcomp>(.0)
#       1 #En esta parte vamos a identificar el resto de tapones que no son rosas, a esos cabrones los dejamos para el final
# ----> 2 images = [cv2.imread("final_project_imgs/%d.jpg"%(i)) for i in range(1, 9)]
#       3 images_copy = images.copy()
#       4 images_copy_gray = images.copy()
#       5 images_aux = images.copy()
#
# NameError: name 'cv2' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-042bcef7a13f> in <module>
#       2 #Pasaremos una doble mascara de hsv que con los parametros correctos podra identificar el color rosa unicamente
#       3
# ----> 4 images = [cv2.imread("final_project_imgs/%d.jpg"%(i)) for i in range(1, 9)]
#       5 images_copy = images.copy()
#       6 images_copy_pink = images.copy()
#
# <ipython-input-3-042bcef7a13f> in <listcomp>(.0)
#       2 #Pasaremos una doble mascara de hsv que con los parametros correctos podra identificar el color rosa unicamente
#       3
# ----> 4 images = [cv2.imread("final_project_imgs/%d.jpg"%(i)) for i in range(1, 9)]
#       5 images_copy = images.copy()
#       6 images_copy_pink = images.copy()
#
# NameError: name 'cv2' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-600fff03eb33> in <module>
#       1 #Una vez encontrados los tapones, sumamos las mascaras para obtener la imagen completa
# ----> 2 images = [cv2.imread("final_project_imgs/%d.jpg"%(i)) for i in range(1, 9)]
#       3 images_copy = images.copy()
#       4 images_final = images.copy()
#       5
#
# <ipython-input-4-600fff03eb33> in <listcomp>(.0)
#       1 #Una vez encontrados los tapones, sumamos las mascaras para obtener la imagen completa
# ----> 2 images = [cv2.imread("final_project_imgs/%d.jpg"%(i)) for i in range(1, 9)]
#       3 images_copy = images.copy()
#       4 images_final = images.copy()
#       5
#
# NameError: name 'cv2' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-75b14e0f012c> in <module>
#       3 import imutils
#       4
# ----> 5 image_original = images.copy()
#       6 cnts = images.copy()
#       7 aux = images.copy()
#
# NameError: name 'images' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3aaa675a1f72> in <module>
#       1 #Ahora identificaremos los centros y hayaremos el área
#       2 #A TRABAJAR PANOLI
# ----> 3 images_area = images.copy()
#       4 image_hsv = images.copy()
#       5 color = []
#
# NameError: name 'images' is not defined
